# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
import numpy as np
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
data_test = pd.read_csv(r"test.csv",usecols=[0,3,6,9,12,15,18,21,24,27])

# %%
data_all = []
for i in range(180):
    data_all.append(data_test.iloc[i:i+1,:].values)
data_all_numpy = np.array(data_all)

# %%
reshaped_data = data_all_numpy.reshape(180, 10)

# 使用 PCA 将数据降到二维
pca = PCA(n_components=2)
data_pca = pca.fit_transform(reshaped_data)

# 使用 t-SNE 将数据降到二维
tsne = TSNE(n_components=2)
data_tsne = tsne.fit_transform(reshaped_data)

# %%
plt.scatter(data_tsne[:,0],data_tsne[:,1])
plt.show()

# %%
kmeans = KMeans(n_clusters=)
